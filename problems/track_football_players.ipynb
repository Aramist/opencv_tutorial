# %%
import cv2

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget

# %%
video_path = "data/football.mov"
cap = cv2.VideoCapture(video_path)
_, sample_image = cap.read()

# %%
sample_image.shape
plt.imshow(sample_image[..., ::-1])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def find_and_label_orange(image: np.ndarray) -> np.ndarray:
    pass

# %%
cv2.namedWindow("frame", cv2.WINDOW_NORMAL)
while True:
    ret, frame = cap.read()
    if not ret:
        cap.set(cv2.CAP_PROP_POS_MSEC, 0)
        continue

    new_im = find_and_label_orange(frame)
    cv2.imshow("frame", new_im)
    inp = cv2.waitKey(1)
    if inp == ord("q"):  # press q to quit
        break
cv2.destroyAllWindows()
